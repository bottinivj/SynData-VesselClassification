# %%
dataset = '1717_SYN_1000'

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, precision_score, recall_score, accuracy_score, roc_curve, auc, f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.preprocessing import LabelEncoder
from ultralytics import YOLO
from sklearn.model_selection import train_test_split
import cv2
import seaborn as sns

# %%
train_dir = str('DS_REAL_SPLITED_' + dataset)

model = YOLO("yolo12n-cls.yaml")

model.train(data=train_dir, epochs=300, imgsz=64, project='YOLO12-RESULTS', name=dataset)
# Out:
# YOLO12n-cls summary: 152 layers, 1,820,976 parameters, 1,820,976 gradients, 3.7 GFLOPs
# New https://pypi.org/project/ultralytics/8.3.231 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.169 🚀 Python-3.11.0rc1 torch-2.0.1+cu118 CUDA:0 (NVIDIA GeForce RTX 4090, 24564MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=DS_REAL_SPLITED_1717_SYN_1000, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=300, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=64, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo12n-cls.yaml, momentum=0.937, mosaic=1.0, multi_scale=False, name=1717_SYN_1000, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=YOLO12-RESULTS, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=YOLO12-RESULTS/1717_SYN_1000, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/train... found 38500 images in 10 classes ✅
# val: /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/val... found 750 images in 10 classes ✅
# test: /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/test... found 750 images in 10 classes ✅
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  2    180864  ultralytics.nn.modules.block.A2C2f           [128, 128, 2, True, 4]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  2    689408  ultralytics.nn.modules.block.A2C2f           [256, 256, 2, True, 1]
#   9                  -1  1    343050  ultralytics.nn.modules.head.Classify         [256, 10]
# YOLO12n-cls summary: 152 layers, 1,731,306 parameters, 1,731,306 gradients, 3.7 GFLOPs
# AMP: running Automatic Mixed Precision (AMP) checks...
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 3.7±0.3 ms, read: 5.0±0.8 MB/s, size: 34.8 KB)
# train: Scanning /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/train... 38500 images, 0 corrupt: 100%|██████████| 38500/38
# train: New cache created: /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/train.cache
# val: Fast image access ✅ (ping: 4.0±0.3 ms, read: 4.8±1.0 MB/s, size: 40.9 KB)
# val: Scanning /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/val... 750 images, 0 corrupt: 100%|██████████| 750/750 [00:01
# val: New cache created: /tf/2025/SEEDS/DS_REAL_SPLITED_1717_SYN_1000/val.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 58 weight(decay=0.0), 59 weight(decay=0.0005), 59 bias(decay=0.0)
# Image sizes 64 train, 64 val
# Using 8 dataloader workers
# Logging results to YOLO12-RESULTS/1717_SYN_1000
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#       1/300     0.602G      2.151          4         64: 100%|██████████| 2407/2407 [02:02<00:00, 19.57it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 19.48it/s]
#                    all      0.296      0.812
#       Epoch    GPU_mem       loss  Instances       Size
#       2/300     0.602G      1.601          4         64: 100%|██████████| 2407/2407 [01:48<00:00, 22.09it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.05it/s]
#                    all      0.368      0.876
#       Epoch    GPU_mem       loss  Instances       Size
#       3/300     0.602G      1.405          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.67it/s]
#                    all      0.453      0.907
#       Epoch    GPU_mem       loss  Instances       Size
#       4/300     0.602G      1.233          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.64it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.22it/s]
#                    all      0.536      0.915
#       Epoch    GPU_mem       loss  Instances       Size
#       5/300     0.602G      1.078          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.58it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.99it/s]
#                    all      0.532      0.919
#       Epoch    GPU_mem       loss  Instances       Size
#       6/300     0.602G     0.9879          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.38it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.08it/s]
#                    all      0.588      0.939
#       Epoch    GPU_mem       loss  Instances       Size
#       7/300     0.602G     0.9117          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.25it/s]
#                    all      0.596      0.951
#       Epoch    GPU_mem       loss  Instances       Size
#       8/300     0.602G     0.8688          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.38it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.37it/s]
#                    all      0.612      0.963
#       Epoch    GPU_mem       loss  Instances       Size
#       9/300     0.602G     0.8274          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.98it/s]
#                    all      0.643      0.961
#       Epoch    GPU_mem       loss  Instances       Size
#      10/300     0.602G     0.7932          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.51it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.88it/s]
#                    all      0.632      0.956
#       Epoch    GPU_mem       loss  Instances       Size
#      11/300     0.602G     0.7734          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.45it/s]
#                    all      0.655      0.961
#       Epoch    GPU_mem       loss  Instances       Size
#      12/300     0.602G     0.7484          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.45it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 23.19it/s]
#                    all      0.664      0.969
#       Epoch    GPU_mem       loss  Instances       Size
#      13/300     0.602G     0.7182          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.27it/s]
#                    all      0.651      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      14/300     0.602G     0.7024          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.46it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.69it/s]
#                    all      0.669      0.971
#       Epoch    GPU_mem       loss  Instances       Size
#      15/300     0.602G     0.6921          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.59it/s]
#                    all      0.668      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      16/300     0.602G     0.6722          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.48it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.19it/s]
#                    all      0.672      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      17/300     0.602G     0.6608          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.47it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.55it/s]
#                    all      0.679      0.979
#       Epoch    GPU_mem       loss  Instances       Size
#      18/300     0.602G     0.6538          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.37it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.02it/s]
#                    all      0.687      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      19/300     0.602G     0.6378          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.58it/s]
#                    all      0.701      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      20/300     0.602G     0.6288          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.45it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.74it/s]
#                    all      0.695      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      21/300     0.602G     0.6299          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.08it/s]
#                    all      0.703      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#      22/300     0.602G     0.6167          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.42it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.32it/s]
#                    all      0.708      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#      23/300     0.602G     0.6057          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.31it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.41it/s]
#                    all      0.716      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      24/300     0.602G     0.6075          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.33it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.82it/s]
#                    all      0.709      0.979
#       Epoch    GPU_mem       loss  Instances       Size
#      25/300     0.602G     0.6003          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.61it/s]
#                    all      0.716      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#      26/300     0.602G     0.5947          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.35it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.86it/s]
#                    all      0.716      0.977
#       Epoch    GPU_mem       loss  Instances       Size
#      27/300     0.602G     0.5817          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.32it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.97it/s]
#                    all       0.72      0.976
#       Epoch    GPU_mem       loss  Instances       Size
#      28/300     0.602G     0.5841          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.40it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 23.06it/s]
#                    all      0.721      0.976
#       Epoch    GPU_mem       loss  Instances       Size
#      29/300     0.602G     0.5768          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.39it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 23.13it/s]
#                    all      0.724      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      30/300     0.602G     0.5743          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.49it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.26it/s]
#                    all      0.721      0.975
#       Epoch    GPU_mem       loss  Instances       Size
#      31/300     0.602G     0.5611          4         64: 100%|██████████| 2407/2407 [01:47<00:00, 22.50it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.54it/s]
#                    all      0.723      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      32/300     0.602G     0.5682          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.59it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.59it/s]
#                    all       0.72      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      33/300     0.602G     0.5591          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.92it/s]
#                    all       0.72      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      34/300     0.602G     0.5538          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.37it/s]
#                    all      0.723      0.973
#       Epoch    GPU_mem       loss  Instances       Size
#      35/300     0.602G      0.546          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.60it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.89it/s]
#                    all      0.721      0.976
#       Epoch    GPU_mem       loss  Instances       Size
#      69/300     0.602G     0.4638          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.44it/s]
#                    all      0.743      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      70/300     0.602G     0.4633          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.56it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.99it/s]
#                    all      0.747      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#      76/300     0.602G     0.4444          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.52it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.62it/s]
#                    all      0.753      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      81/300     0.602G     0.4363          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.55it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.81it/s]
#                    all      0.753      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      82/300     0.602G     0.4376          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.53it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.72it/s]
#                    all      0.757      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#      83/300     0.602G     0.4456         16         64:  16%|█▌        | 374/2407 [00:16<01:21, 24.99it/s]IOPub message rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_msg_rate_limit`.
#
# Current values:
# ServerApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
#      84/300     0.602G     0.4403          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.70it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.96it/s]
#                    all      0.763      0.988
#       Epoch    GPU_mem       loss  Instances       Size
#      91/300     0.602G     0.4235          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.66it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 21.80it/s]
#                    all      0.772      0.985
#       Epoch    GPU_mem       loss  Instances       Size
#      95/300     0.602G     0.4258          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.24it/s]
#                    all      0.773      0.983
#       Epoch    GPU_mem       loss  Instances       Size
#     100/300     0.602G     0.4162          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.62it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.33it/s]
#                    all      0.772      0.984
#       Epoch    GPU_mem       loss  Instances       Size
#     105/300     0.602G     0.4142          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.63it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.44it/s]
#                    all      0.771      0.987
#       Epoch    GPU_mem       loss  Instances       Size
#     106/300     0.602G     0.4182          4         64: 100%|██████████| 2407/2407 [01:46<00:00, 22.60it/s]
#                classes   top1_acc   top5_acc: 100%|██████████| 24/24 [00:01<00:00, 22.43it/s]
#                    all      0.771      0.989
#       Epoch    GPU_mem       loss  Instances       Size
#     107/300     0.602G      0.398         16         64:  15%|█▌        | 366/2407 [00:16<01:31, 22.34it/s]

# %%
from pathlib import Path
from PIL import Image
from sklearn.metrics import classification_report

def avaliar_modelo(model, val_path, imgsz=64, verbose=False):

    val_path = Path(val_path)

    class_names = sorted([d.name for d in val_path.iterdir() if d.is_dir()])
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(class_names)}

    y_true = []
    y_pred = []

    for cls_name in class_names:
        cls_dir = val_path / cls_name
        label = class_to_idx[cls_name]

        for img_path in cls_dir.glob("*.*"):  # jpg, png, etc.
            try:
                img = Image.open(img_path).convert("RGB")
                results = model.predict(img, imgsz=imgsz, verbose=False)
                pred = int(results[0].probs.top1)

                y_true.append(label)
                y_pred.append(pred)

                if verbose:
                    print(f"Imagem: {img_path.name} | Real: {cls_name} | Previsto: {class_names[pred]}")

            except Exception as e:
                print(f"[ERRO] Falha ao processar {img_path.name}: {e}")

    y_true = np.array(y_true)
    y_pred = np.array(y_pred)

    acc = accuracy_score(y_true, y_pred)
    report = classification_report(y_true, y_pred, target_names=class_names)

    print(f"\n🔍 Acurácia: {acc:.4f}")
    print(report)

    return y_true, y_pred, report

# %%
# Carregue seu modelo (pré-treinado ou treinado)
model = YOLO(str('YOLO12-RESULTS/' + dataset + '/weights/best.pt'))

# Caminho para pasta de validação
val_path = str('DS_REAL_SPLITED_' + dataset + '/test')

# Avaliação
y_true, y_pred, relatorio = avaliar_modelo(model, val_path, imgsz=64, verbose=False)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py:459: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# 🔍 Acurácia: 0.7680
#                    precision    recall  f1-score   support
#
#       BULKCARRIER       0.70      0.37      0.49        75
#     CONTAINERSHIP       0.79      0.87      0.83        75
#      GENERALCARGO       0.58      0.64      0.61        75
# OILPRODUCTSTANKER       0.71      0.43      0.53        75
#    PASSENGERSSHIP       0.92      0.88      0.90        75
#            TANKER       0.51      0.84      0.64        75
#           TRAWLER       0.87      0.83      0.85        75
#               TUG       0.89      0.91      0.90        75
#   VEHICLESCARRIER       0.94      0.96      0.95        75
#             YACHT       0.89      0.96      0.92        75
#
#          accuracy                           0.77       750
#         macro avg       0.78      0.77      0.76       750
#      weighted avg       0.78      0.77      0.76       750

# %%
def plotar_metricas(y_true, y_pred):
    """
    Gera os gráficos de Acurácia, Precisão, Recall e a Matriz de Confusão.
    """
    # 1. Acurácia
    accuracy = accuracy_score(y_true, y_pred)

    # 2. Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    # 3. Precision
    precision = precision_score(y_true, y_pred, average='macro')

    # 4. Recall
    recall = recall_score(y_true, y_pred, average='macro')

    #5. F1-Score
    f1 = f1_score(y_true, y_pred, average='macro')

    # Plot 1: Gráfico de Acurácia, Precisão e Recall
    metrics = [accuracy, precision, recall, f1]
    metrics_names = ['Acurácia', 'Precisão', 'Recall', 'f1_score']

    plt.figure(figsize=(8, 6))
    plt.bar(metrics_names, metrics, color=['blue', 'green', 'orange', 'yellow'])
    plt.title('Acurácia, Precisão, Recall & F1')
    plt.ylim(0, 1)
    plt.ylabel('Valor')
    for i, value in enumerate(metrics):
        plt.text(i, value + 0.02, f'{value:.4f}', ha='center', va='bottom', fontsize=12)
    plt.show()

    # Plot 2: Matriz de Confusão
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues', xticklabels=np.arange(1, cm.shape[1] + 1), yticklabels=np.arange(1, cm.shape[0] + 1))
    plt.title('Matriz de Confusão')
    plt.xlabel('Predições')
    plt.ylabel('Verdadeiros')
    plt.show()

    print(f'Acurácia: {accuracy:.4f}')
    print(f'Precision: {precision:.4f}')
    print(f'Recall: {recall:.4f}')
    print(f'F1 Score: {f1:.4f}')
    print(f'Confusion Matrix:\n{cm}')

# %%
# %matplotlib inline
plotar_metricas(y_true, y_pred)
# Out:
# Acurácia: 0.7680
# Precision: 0.7803
# Recall: 0.7680
# F1 Score: 0.7611
# Confusion Matrix:
# [[28  3 18  6  1 13  1  3  1  1]
#  [ 2 65  2  1  0  4  0  0  1  0]
#  [ 5  8 48  2  0 11  0  1  0  0]
#  [ 3  1  6 32  0 29  3  1  0  0]
#  [ 0  1  0  0 66  0  0  1  1  6]
#  [ 2  0  6  4  0 63  0  0  0  0]
#  [ 0  2  3  0  2  0 62  2  2  2]
#  [ 0  2  0  0  0  0  5 68  0  0]
#  [ 0  0  0  0  1  2  0  0 72  0]
#  [ 0  0  0  0  2  1  0  0  0 72]]
